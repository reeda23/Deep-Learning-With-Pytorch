# %% [markdown]
# <a href="https://colab.research.google.com/github/reeda23/Deep-Learning-With-Pytorch/blob/main/Backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Backpropagation![ChainRule.PNG](data:image/png;base64,...)

# %% [markdown]
# So for every computation that we do Pytorch will create a graph for us. So for each node we apply one operation or one function with some inputs and then get an output. In the below case we use a multiplication operation so we multiply x and y and get z. So we calculate local gradients and we can use them later in chain rule to get the final gradient.
#
# Athe very end we calculate a loss function that we want to minimize so wwe have to calculate the gradient of this loss with respect to our parameter x in the begining.
# ![ComputationalGraphChainRule.PNG](data:image/png;base64,...)

# %% [markdown]
# # Concept of Backpropagation
#
# 1) Forward pass: Compute Loss <br>
# 2) Compute Local gradients <br>
# 3) Backward pass: Compute dLoss/ dWeights using the Chain Rule
#
# ![BP.PNG](data:image/png;base64,...)

# %%
import torch

x = torch.tensor(1.0)
y = torch.tensor(2.0)

w = torch.tensor(1.0, requires_grad=True)

#forward pass and compute the loss
y_hat = w * x
loss = (y_hat - y)**2

print(loss)


#backward pass
#pytorch will compute local gradients automatically for us and also computes the 
#backward pass automatically for us
loss.backward()
print(w.grad)


#update weights
#next forward and backwards
# Out:
# tensor(1., grad_fn=<PowBackward0>)
# tensor(-2.)
